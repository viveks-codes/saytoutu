# %% [markdown]
# # Import Lib and import data

# %%
import pandas as pd
gurl = "https://docs.google.com/spreadsheets/d/1QyRJTNd1eIOxjQXzOkhHnAfEvmZGTIix45fF24ylfck/gviz/tq?tqx=out:csv&sheet=confession"
data = pd.read_csv(gurl)

# %%
data
# Out:
#               Name         dept  year  \
# 0      Parth Desai        Other   1.0
# 1              Hai     Computer   2.0
# 2          Jignesh       Others   1.0
# 3              All       Others   0.0
# 4              ALL        FALSE   0.0
# ..             ...          ...   ...
# 75     MIHIR GOHEL           IT   1.0
# 76  Bappu his self  Automobiles   4.0
# 77        Some one           IT   1.0
# 78        Some one           IT   1.0
# 79   Ayush parmar            IT   1.0
#
#                                            confession
# 0   Parth tera name mene DesiParth rakha he Desai ...
# 1                                                Jjdj
# 2   Bhai jignesh, mere 750 rps wapis de de, kb tk ...
# 3        Corona ma Social destansin nu palan karo m*m
# 4   अगर दिल न मिले तो प्यार अधूरा होता है,\r\nचाँद...
# ..                                                ...
# 75                Beta aap thoda sambhal ke kam krna.
# 76  Kuchh confess karna ho to directly muje msg ka...
# 77   ek chhokri 🤮🤮🤮🤮 che ane vem ma che e k e kaik...
# 78   ek chhokri 🤮🤮🤮🤮 che ane vem ma che e k e kaik...
# 79  karta sabkuchh he par dikha ta kuchh nahi 😒(ba...
#
# [80 rows x 4 columns]

# %% [markdown]
# # Let's remove duplicate value

# %%
data.drop_duplicates(subset ="confession",
                     keep = "last", inplace = True)

# %% [markdown]
# # Data Wranglling

# %%
data["year"].fillna("9", inplace = True)
data['year'] = data['year'].astype(int)
data['dept'] = data['dept'].replace(['FALSE'],['Not want to mention'])

# %%
data.tail()
# Out:
#               Name         dept  year  \
# 73     mihir gohel           IT     1
# 75     MIHIR GOHEL           IT     1
# 76  Bappu his self  Automobiles     4
# 78        Some one           IT     1
# 79   Ayush parmar            IT     1
#
#                                            confession
# 73  h*r*l ne no adata koi baki ... \r\n...baki mih...
# 75                Beta aap thoda sambhal ke kam krna.
# 76  Kuchh confess karna ho to directly muje msg ka...
# 78   ek chhokri 🤮🤮🤮🤮 che ane vem ma che e k e kaik...
# 79  karta sabkuchh he par dikha ta kuchh nahi 😒(ba...

# %%
data
# Out:
#                                                  Name                 dept  \
# 0                                         Parth Desai                Other
# 1                                                 Hai             Computer
# 2                                             Jignesh               Others
# 3                                                 All               Others
# 4                                                 ALL  Not want to mention
# 5                                             Shivani  Not want to mention
# 6                                  To:- Rutvik Parmar              Pharm.D
# 7                                       Rutvik Parmar               Others
# 8                                    naam nahi batana  Not want to mention
# 9                            all the 2015-2019 batch   Not want to mention
# 10                               Don't want to reveal  Not want to mention
# 11                                              Hello                Civil
# 12                                         CE and IT                Others
# 13                                         Kate Marsh             Computer
# 14                                              Vivek                  MCA
# 16                                              admin                AI&DC
# 17                                            Kavita                 AI&DC
# 18                                              vivek                AI&DC
# 19                 Anyone who creates this situation   Not want to mention
# 22                                     jatin Sachdeva                   IT
# 23                                               Pori                Civil
# 24                                                All               Others
# 25                                        Kajal Singh                AI&DC
# 26                                              Admin  Not want to mention
# 28                                           Everyone                AI&DC
# 29                                    Hunaid Nakhuda                 AI&DC
# 31                            Krina computer diwaliba             Computer
# 32                                       Akshatt shah  Not want to mention
# 33                                           Everyone  Not want to mention
# 36                                             Mezu❤️  Not want to mention
# 37                                       Mansi Patel             Chemistry
# 38                                             komal              Computer
# 39                                     Sanjana rajput                  BBA
# 40                                   Dharmil Jariwala       Cyber Security
# 41                                             Sahil   Not want to mention
# 42                                              Pooja             Computer
# 46                                        Nisarg Rana                AI&DC
# 48                                               Zeel               Others
# 49            2-4 students ko baad karke baki sub log                AI&DC
# 58            2-4 students ko baad karke baki sub log                AI&DC
# 59           2-4 students ko baad kar ke baki sab log                AI&DC
# 60  2-4 students ko baad karke baki sub AI&DC ke s...                AI&DC
# 61                               Parth malvi diwaliba             Computer
# 64                                        mihir gohel                   IT
# 65                                      Smeet khokahr             Computer
# 66                                    Smeet khokhar🐒🐒             Computer
# 67                                         Prit gohel       Cyber Security
# 68                                     Niraj vekriya                    IT
# 69                                       Mihir gohil                    IT
# 70                                       Raj rabadiya                   IT
# 71                                       Raj rabadiya                   IT
# 72                                               Raj                    IT
# 73                                        mihir gohel                   IT
# 75                                        MIHIR GOHEL                   IT
# 76                                     Bappu his self          Automobiles
# 78                                           Some one                   IT
# 79                                      Ayush parmar                    IT
#
#     year                                         confession
# 0      1  Parth tera name mene DesiParth rakha he Desai ...
# 1      2                                               Jjdj
# 2      1  Bhai jignesh, mere 750 rps wapis de de, kb tk ...
# 3      0       Corona ma Social destansin nu palan karo m*m
# 4      0  अगर दिल न मिले तो प्यार अधूरा होता है,\r\nचाँद...
# 5      0  I am really shy to say you directly, but I LOV...
# 6      2  Bhai kab tak akele akele cricket khelegaa hume...
# 7      2  Bhai harroz akele akele cricket khelate ho kab...
# 8      9          I love you pagal😘😘❤️❤️ but as a Friend😘😘😘
# 9      9  I miss all the great time \r\nI miss PUSHPAM T...
# 10     1  You used me to the fullest didn't expect that ...
# 11     2                                          VVvgvgvgv
# 12     1  Ye First year CE and IT wale kitne Chalu hain ...
# 13     9  I really Like Like Your Personality, Let's mee...
# 14     1                                           Fuck you
# 16     1                            its not ai&dc its ai&ds
# 17     1                     I think vivek patel likes you
# 18     1                          I think kavita likes you
# 19     0  Whoever reads this, first of all have a good d...
# 22     9                                      gaandu hu mai
# 23     2                                        I love you
# 24     0     Notice Ab Firse Char dinka lockdown ho gaya...
# 25     1  Hostel me Raat ko Dusre baccho ko nahi darate....
# 26     9                          Waah bete moj kardi #Test
# 28     0                  In the end it doesn't even matter
# 29     1  I dont sleep coz when I do all I dream are dre...
# 31     1                                       I love you ❤
# 32     9                          We Miss Your Voice! ❤❤❤❤❤
# 33     1  Mai Ma*******d hu jo iss college me aaya hun.....
# 36     1                        I love your smile Mezbin ❤️
# 37     3  Mansi I am your friend.. who wants to tell u t...
# 38     4                                   i need your yes😎
# 39     1  Oo apna attitude apne pass rakh na ok \r\nHame...
# 40     1  Ye banda dusro kem kam me aapni nak ghusedta h...
# 41     1  Sbse bda wala Topper he lekin sbko toppy phena...
# 42     2                                   Love You Babu ❤❤
# 46     1               Online classs me gana bajata hai🔥🔥🤣🤣
# 48     2            Attitude and ego level is very high 😏😐😑
# 49     1  Sabhi log teachers ke sath rahte hai baki aap ...
# 58     1  Sabhi log teachers ke sath rahte hai baki aap ...
# 59     1  Sabhi log teachers ke sath rahte hai baki aap ...
# 60     1  Salo intna kaya maza aata hai teachers ke pass...
# 61     1  Yeh bande ko har bandi pasand he patalab koi b...
# 64     1   Hu sachu farm a bija ni fortune lai ne gyo to...
# 65     1  Ye banda IT valo se panga lene vala hai hai🤦🏼‍...
# 66     1  Ye banda IT valo se panga lene vala hai😂😂😂\r\n...
# 67     1               Hanma thi DJ nai vagtu lectures ma🤪🤪
# 68     1  Badhi girls ne massage kari ne key me koi sath...
# 69     1  Ye mat karo yarr\r\nBahot hi manhus lag rahai ...
# 70     1    Bhai 20 rs aap ne mari gadi ma petrol nthi 🥺🤪😂
# 71     1  Bhai 20 rs aap ne mari gadi ma petrol nthi 🥺🥺🤪😂🔥🔥
# 72     1    Bhai 20 rs aap ne petrol nthi mari gadi ma 🥺🤪😂😂
# 73     1  h*r*l ne no adata koi baki ... \r\n...baki mih...
# 75     1                Beta aap thoda sambhal ke kam krna.
# 76     4  Kuchh confess karna ho to directly muje msg ka...
# 78     1   ek chhokri 🤮🤮🤮🤮 che ane vem ma che e k e kaik...
# 79     1  karta sabkuchh he par dikha ta kuchh nahi 😒(ba...

# %%
data.tail()
# Out:
#               Name         dept  year  \
# 73     mihir gohel           IT     1
# 75     MIHIR GOHEL           IT     1
# 76  Bappu his self  Automobiles     4
# 78        Some one           IT     1
# 79   Ayush parmar            IT     1
#
#                                            confession
# 73  h*r*l ne no adata koi baki ... \r\n...baki mih...
# 75                Beta aap thoda sambhal ke kam krna.
# 76  Kuchh confess karna ho to directly muje msg ka...
# 78   ek chhokri 🤮🤮🤮🤮 che ane vem ma che e k e kaik...
# 79  karta sabkuchh he par dikha ta kuchh nahi 😒(ba...

# %%
personNum = int(input("Enter a number"))
namec = data["Name"][personNum]
deptc = data["dept"][personNum]
yearc = data["year"][personNum]
if(data["year"][personNum]==9):
    yearc = "Not want to mention"
confessionc = data["confession"][personNum]
# Out:
# Enter a number79

# %%
namec
# Out:
# 'Ayush parmar '

# %%
deptc
# Out:
# 'IT'

# %%
yearc
# Out:
# 1

# %%
confessionc
# Out:
# 'karta sabkuchh he par dikha ta kuchh nahi 😒(badha kand karva ma aagal)'

# %%
str = """        
<div class=\"row\">

    <div class=\"col s12 m6 l6\">

        <div class=\"card blue\">

            <div class=\"card-content white-text\">

                <span class=\"card-title\">To: {} </span>
                    <span>Department: {}</span><br>
                        <span>Year: {}</span>
                            <p>Confession:{}</p>
            </div>
        </div>
    </div>

""";

# %%
str = str.format(namec,deptc,yearc,confessionc)

# %%
str
# Out:
# '        \n<div class="row">\n\n    <div class="col s12 m6 l6">\n\n        <div class="card blue">\n\n            <div class="card-content white-text">\n\n                <span class="card-title">To: MIHIR GOHEL </span>\n                    <span>Department: IT</span><br>\n                        <span>Year: 1</span>\n                            <p>Confession:Beta aap thoda sambhal ke kam krna.</p>\n            </div>\n        </div>\n    </div>\n\n'

# %% [markdown]
# <h1>Don't run below cells blindly </h1>
#     <h2>Please <a href="view.html">Click Here</a></h2>
#     <p>Notice here! CSS WIll Not work on local host</p>

# %%
f = open("view.html", mode="r", encoding="utf-8")
contents = f.readlines()
f.close()
#this code will append html code on line no 65
contents.insert(65, str)

f = open("view.html", mode="w", encoding="utf-8")
contents = "".join(contents)
f.write(contents)
f.close()
