# %% [markdown]
# # Import Lib and import data

# %%
import pandas as pd
gurl = "https://docs.google.com/spreadsheets/d/1QyRJTNd1eIOxjQXzOkhHnAfEvmZGTIix45fF24ylfck/gviz/tq?tqx=out:csv&sheet=confession"
data = pd.read_csv(gurl)

# %%
data
# Out:
#                                   Name                 dept  year  \
# 0                          Parth Desai                Other   1.0
# 1                                  Hai             Computer   2.0
# 2                              Jignesh               Others   1.0
# 3                                  All               Others   0.0
# 4                                  ALL                FALSE   0.0
# 5                              Shivani                FALSE   0.0
# 6                   To:- Rutvik Parmar              Pharm.D   2.0
# 7                        Rutvik Parmar               Others   2.0
# 8                     naam nahi batana                FALSE   NaN
# 9             all the 2015-2019 batch                 FALSE   NaN
# 10                Don't want to reveal                FALSE   1.0
# 11                               Hello                Civil   2.0
# 12                          CE and IT                Others   1.0
# 13                          Kate Marsh             Computer   NaN
# 14                               Vivek                  MCA   1.0
# 15                               admin                AI&DC   1.0
# 16                               admin                AI&DC   1.0
# 17                             Kavita                 AI&DC   1.0
# 18                               vivek                AI&DC   1.0
# 19  Anyone who creates this situation   Not want to mention   0.0
# 20                      jatin Sachdeva                   IT   NaN
# 21                      jatin Sachdeva                   IT   NaN
# 22                      jatin Sachdeva                   IT   NaN
# 23                                Pori                Civil   2.0
# 24                                 All               Others   0.0
# 25                         Kajal Singh                AI&DC   1.0
# 26                               Admin  Not want to mention   NaN
# 27                            Everyone                AI&DC   0.0
# 28                            Everyone                AI&DC   0.0
# 29                     Hunaid Nakhuda                 AI&DC   1.0
# 30             Krina computer diwaliba             Computer   1.0
# 31             Krina computer diwaliba             Computer   1.0
# 32                        Akshatt shah  Not want to mention   NaN
# 33                            Everyone  Not want to mention   1.0
# 34                              Mezu❤️  Not want to mention   1.0
# 35                              Mezu❤️  Not want to mention   1.0
# 36                              Mezu❤️  Not want to mention   1.0
# 37                        Mansi Patel             Chemistry   3.0
#
#                                            confession
# 0   Parth tera name mene DesiParth rakha he Desai ...
# 1                                                Jjdj
# 2   Bhai jignesh, mere 750 rps wapis de de, kb tk ...
# 3        Corona ma Social destansin nu palan karo m*m
# 4   अगर दिल न मिले तो प्यार अधूरा होता है,\r\nचाँद...
# 5   I am really shy to say you directly, but I LOV...
# 6   Bhai kab tak akele akele cricket khelegaa hume...
# 7   Bhai harroz akele akele cricket khelate ho kab...
# 8           I love you pagal😘😘❤️❤️ but as a Friend😘😘😘
# 9   I miss all the great time \r\nI miss PUSHPAM T...
# 10  You used me to the fullest didn't expect that ...
# 11                                          VVvgvgvgv
# 12  Ye First year CE and IT wale kitne Chalu hain ...
# 13  I really Like Like Your Personality, Let's mee...
# 14                                           Fuck you
# 15                            its not ai&dc its ai&ds
# 16                            its not ai&dc its ai&ds
# 17                     I think vivek patel likes you
# 18                          I think kavita likes you
# 19  Whoever reads this, first of all have a good d...
# 20                                      gaandu hu mai
# 21                                      gaandu hu mai
# 22                                      gaandu hu mai
# 23                                        I love you
# 24     Notice Ab Firse Char dinka lockdown ho gaya...
# 25  Hostel me Raat ko Dusre baccho ko nahi darate....
# 26                          Waah bete moj kardi #Test
# 27                  In the end it doesn't even matter
# 28                  In the end it doesn't even matter
# 29  I dont sleep coz when I do all I dream are dre...
# 30                                       I love you ❤
# 31                                       I love you ❤
# 32                          We Miss Your Voice! ❤❤❤❤❤
# 33  Mai Ma*******d hu jo iss college me aaya hun.....
# 34                        I love your smile Mezbin ❤️
# 35                        I love your smile Mezbin ❤️
# 36                        I love your smile Mezbin ❤️
# 37  Mansi I am your friend.. who wants to tell u t...

# %% [markdown]
# # Let's remove duplicate value

# %%
data.drop_duplicates(subset ="confession",
                     keep = "last", inplace = True)

# %% [markdown]
# # Data Wranglling

# %%
data["year"].fillna("9", inplace = True)
data['year'] = data['year'].astype(int)
data['dept'] = data['dept'].replace(['FALSE'],['Not want to mention'])

# %%
data.tail()
# Out:
#                        Name                 dept  year  \
# 31  Krina computer diwaliba             Computer     1
# 32             Akshatt shah  Not want to mention     9
# 33                 Everyone  Not want to mention     1
# 36                   Mezu❤️  Not want to mention     1
# 37             Mansi Patel             Chemistry     3
#
#                                            confession
# 31                                       I love you ❤
# 32                          We Miss Your Voice! ❤❤❤❤❤
# 33  Mai Ma*******d hu jo iss college me aaya hun.....
# 36                        I love your smile Mezbin ❤️
# 37  Mansi I am your friend.. who wants to tell u t...

# %%
data
# Out:
#                                   Name                 dept  year  \
# 0                          Parth Desai                Other     1
# 1                                  Hai             Computer     2
# 2                              Jignesh               Others     1
# 3                                  All               Others     0
# 4                                  ALL  Not want to mention     0
# 5                              Shivani  Not want to mention     0
# 6                   To:- Rutvik Parmar              Pharm.D     2
# 7                        Rutvik Parmar               Others     2
# 8                     naam nahi batana  Not want to mention     9
# 9             all the 2015-2019 batch   Not want to mention     9
# 10                Don't want to reveal  Not want to mention     1
# 11                               Hello                Civil     2
# 12                          CE and IT                Others     1
# 13                          Kate Marsh             Computer     9
# 14                               Vivek                  MCA     1
# 16                               admin                AI&DC     1
# 17                             Kavita                 AI&DC     1
# 18                               vivek                AI&DC     1
# 19  Anyone who creates this situation   Not want to mention     0
# 22                      jatin Sachdeva                   IT     9
# 23                                Pori                Civil     2
# 24                                 All               Others     0
# 25                         Kajal Singh                AI&DC     1
# 26                               Admin  Not want to mention     9
# 28                            Everyone                AI&DC     0
# 29                     Hunaid Nakhuda                 AI&DC     1
# 31             Krina computer diwaliba             Computer     1
# 32                        Akshatt shah  Not want to mention     9
# 33                            Everyone  Not want to mention     1
# 36                              Mezu❤️  Not want to mention     1
# 37                        Mansi Patel             Chemistry     3
#
#                                            confession
# 0   Parth tera name mene DesiParth rakha he Desai ...
# 1                                                Jjdj
# 2   Bhai jignesh, mere 750 rps wapis de de, kb tk ...
# 3        Corona ma Social destansin nu palan karo m*m
# 4   अगर दिल न मिले तो प्यार अधूरा होता है,\r\nचाँद...
# 5   I am really shy to say you directly, but I LOV...
# 6   Bhai kab tak akele akele cricket khelegaa hume...
# 7   Bhai harroz akele akele cricket khelate ho kab...
# 8           I love you pagal😘😘❤️❤️ but as a Friend😘😘😘
# 9   I miss all the great time \r\nI miss PUSHPAM T...
# 10  You used me to the fullest didn't expect that ...
# 11                                          VVvgvgvgv
# 12  Ye First year CE and IT wale kitne Chalu hain ...
# 13  I really Like Like Your Personality, Let's mee...
# 14                                           Fuck you
# 16                            its not ai&dc its ai&ds
# 17                     I think vivek patel likes you
# 18                          I think kavita likes you
# 19  Whoever reads this, first of all have a good d...
# 22                                      gaandu hu mai
# 23                                        I love you
# 24     Notice Ab Firse Char dinka lockdown ho gaya...
# 25  Hostel me Raat ko Dusre baccho ko nahi darate....
# 26                          Waah bete moj kardi #Test
# 28                  In the end it doesn't even matter
# 29  I dont sleep coz when I do all I dream are dre...
# 31                                       I love you ❤
# 32                          We Miss Your Voice! ❤❤❤❤❤
# 33  Mai Ma*******d hu jo iss college me aaya hun.....
# 36                        I love your smile Mezbin ❤️
# 37  Mansi I am your friend.. who wants to tell u t...

# %%
data.tail()
# Out:
#                        Name                 dept  year  \
# 31  Krina computer diwaliba             Computer     1
# 32             Akshatt shah  Not want to mention     9
# 33                 Everyone  Not want to mention     1
# 36                   Mezu❤️  Not want to mention     1
# 37             Mansi Patel             Chemistry     3
#
#                                            confession
# 31                                       I love you ❤
# 32                          We Miss Your Voice! ❤❤❤❤❤
# 33  Mai Ma*******d hu jo iss college me aaya hun.....
# 36                        I love your smile Mezbin ❤️
# 37  Mansi I am your friend.. who wants to tell u t...

# %%
personNum = int(input("Enter a number"))
namec = data["Name"][personNum]
deptc = data["dept"][personNum]
yearc = data["year"][personNum]
if(data["year"][personNum]==9):
    yearc = "Not want to mention"
confessionc = data["confession"][personNum]
# Out:
# Enter a number37

# %%
namec
# Out:
# 'Mansi Patel '

# %%
deptc
# Out:
# 'Chemistry'

# %%
yearc
# Out:
# 3

# %%
str = """        
<div class=\"row\">

    <div class=\"col s12 m6 l6\">

        <div class=\"card blue\">

            <div class=\"card-content white-text\">

                <span class=\"card-title\">To: {} </span>
                    <span>Department: {}</span><br>
                        <span>Year: {}</span>
                            <p>Confession:{}</p>
            </div>
        </div>
    </div>

""";

# %%
str = str.format(namec,deptc,yearc,confessionc)

# %%
str
# Out:
# '        \n<div class="row">\n\n    <div class="col s12 m6 l6">\n\n        <div class="card blue">\n\n            <div class="card-content white-text">\n\n                <span class="card-title">To: Mansi Patel  </span>\n                    <span>Department: Chemistry</span><br>\n                        <span>Year: 3</span>\n                            <p>Confession:Mansi I am your friend.. who wants to tell u that  by someone love you in our class</p>\n            </div>\n        </div>\n    </div>\n\n'

# %% [markdown]
# <h1>Don't run below cells blindly </h1>
#     <h2>Please <a href="view.html">Click Here</a></h2>
#     <p>Notice here! CSS WIll Not work on local host</p>

# %%
f = open("view.html", mode="r", encoding="utf-8")
contents = f.readlines()
f.close()
#this code will append html code on line no 65
contents.insert(65, str)

f = open("view.html", mode="w", encoding="utf-8")
contents = "".join(contents)
f.write(contents)
f.close()
